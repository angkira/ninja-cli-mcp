# %%
print("Test 1: Basic Python")

# %%
print("Test 2: Import pandas")

print("pandas imported")

# %%
print("Test 3: Import matplotlib with Agg backend")
import matplotlib


matplotlib.use("Agg")

print("matplotlib imported")

# %%
print("Test 4: Import seaborn")
import seaborn as sns


print("seaborn imported")

# %%
print("Test 5: Set seaborn style")
sns.set_style("whitegrid")
print("style set")
